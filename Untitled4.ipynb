# %%
import tensorflow as tf
import zipfile as zf
import numpy as np
from PIL import Image
import os
import pandas as pd
from pathlib import Path
import pickle
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
i = 1
data = []
labels = []




df = pd.read_csv(r'D:\New folder\labeals.csv')

# %%
for root,dirs,files in os.walk(r'D:\New folder\train_short'):
   for file in files:
      if file.endswith('.jpeg'):
         s = file.split('.')[0]
         dfrow = df[df['image']==s].index.values.astype(int)[0]
         labels.append(df.iloc[dfrow]['level'])
         imgpath = os.path.join(root,file)
         img = Image.open(imgpath)
         print(imgpath)
         data.append(np.array(img).reshape(512,512,3))
         print(len(data))
         i = i+1

print("datarralen="+str(len(data)))
print("labelarrlen="+str(len(labels)))
# Out:
# D:\New folder\train_short\1000_left.jpeg
# 1
# D:\New folder\train_short\1000_right.jpeg
# 2
# D:\New folder\train_short\1002_left.jpeg
# 3
# D:\New folder\train_short\1002_right.jpeg
# 4
# D:\New folder\train_short\1008_left.jpeg
# 5
# D:\New folder\train_short\1008_right.jpeg
# 6
# D:\New folder\train_short\100_left.jpeg
# 7
# D:\New folder\train_short\100_right.jpeg
# 8
# D:\New folder\train_short\1011_left.jpeg
# 9
# D:\New folder\train_short\1011_right.jpeg
# 10
# D:\New folder\train_short\1012_left.jpeg
# 11
# D:\New folder\train_short\1012_right.jpeg
# 12
# D:\New folder\train_short\1017_left.jpeg
# 13
# D:\New folder\train_short\1017_right.jpeg
# 14
# D:\New folder\train_short\1020_left.jpeg
# 15
# D:\New folder\train_short\1020_right.jpeg
# 16
# D:\New folder\train_short\1021_left.jpeg
# 17
# D:\New folder\train_short\1021_right.jpeg
# 18
# D:\New folder\train_short\1024_left.jpeg
# 19
# D:\New folder\train_short\1024_right.jpeg
# 20
# D:\New folder\train_short\1027_left.jpeg
# 21
# D:\New folder\train_short\1027_right.jpeg
# 22
# D:\New folder\train_short\1029_left.jpeg
# 23
# D:\New folder\train_short\1029_right.jpeg
# 24
# D:\New folder\train_short\102_left.jpeg
# 25
# D:\New folder\train_short\102_right.jpeg
# 26
# D:\New folder\train_short\1030_left.jpeg
# 27
# D:\New folder\train_short\1030_right.jpeg
# 28
# D:\New folder\train_short\1032_left.jpeg
# 29
# D:\New folder\train_short\1032_right.jpeg
# 30
# D:\New folder\train_short\1034_left.jpeg
# 31
# D:\New folder\train_short\1034_right.jpeg
# 32
# D:\New folder\train_short\1035_left.jpeg
# 33
# D:\New folder\train_short\1035_right.jpeg
# 34
# D:\New folder\train_short\1036_left.jpeg
# 35
# D:\New folder\train_short\1036_right.jpeg
# 36
# D:\New folder\train_short\1037_left.jpeg
# 37
# D:\New folder\train_short\1037_right.jpeg
# 38
# D:\New folder\train_short\1040_left.jpeg
# 39
# D:\New folder\train_short\1040_right.jpeg
# 40
# D:\New folder\train_short\1041_left.jpeg
# 41
# D:\New folder\train_short\1041_right.jpeg
# 42
# D:\New folder\train_short\1042_left.jpeg
# 43
# D:\New folder\train_short\1042_right.jpeg
# 44
# D:\New folder\train_short\1043_left.jpeg
# 45
# D:\New folder\train_short\1043_right.jpeg
# 46
# D:\New folder\train_short\1044_left.jpeg
# 47
# D:\New folder\train_short\1044_right.jpeg
# 48
# D:\New folder\train_short\1047_left.jpeg
# 49
# D:\New folder\train_short\1047_right.jpeg
# 50
# D:\New folder\train_short\1049_left.jpeg
# 51
# D:\New folder\train_short\1049_right.jpeg
# 52
# D:\New folder\train_short\104_left.jpeg
# 53
# D:\New folder\train_short\104_right.jpeg
# 54
# D:\New folder\train_short\1050_left.jpeg
# 55
# D:\New folder\train_short\1050_right.jpeg
# 56
# D:\New folder\train_short\1051_left.jpeg
# 57
# D:\New folder\train_short\1051_right.jpeg
# 58
# D:\New folder\train_short\1052_left.jpeg
# 59
# D:\New folder\train_short\1052_right.jpeg
# 60
# D:\New folder\train_short\1055_left.jpeg
# 61
# D:\New folder\train_short\1055_right.jpeg
# 62
# D:\New folder\train_short\1056_left.jpeg
# 63
# D:\New folder\train_short\1056_right.jpeg
# 64
# D:\New folder\train_short\1057_left.jpeg
# 65
# D:\New folder\train_short\1057_right.jpeg
# 66
# D:\New folder\train_short\1058_left.jpeg
# 67
# D:\New folder\train_short\1058_right.jpeg
# 68
# D:\New folder\train_short\1059_left.jpeg
# 69
# D:\New folder\train_short\1059_right.jpeg
# 70
# D:\New folder\train_short\1061_left.jpeg
# 71
# D:\New folder\train_short\1061_right.jpeg
# 72
# D:\New folder\train_short\1070_left.jpeg
# 73
# D:\New folder\train_short\1070_right.jpeg
# 74
# D:\New folder\train_short\1073_left.jpeg
# 75
# D:\New folder\train_short\1073_right.jpeg
# 76
# D:\New folder\train_short\1075_left.jpeg
# 77
# D:\New folder\train_short\1075_right.jpeg
# 78
# D:\New folder\train_short\1076_left.jpeg
# 79
# D:\New folder\train_short\1076_right.jpeg
# 80
# D:\New folder\train_short\1077_left.jpeg
# 81
# D:\New folder\train_short\1077_right.jpeg
# 82
# D:\New folder\train_short\1084_left.jpeg
# 83
# D:\New folder\train_short\1084_right.jpeg
# 84
# D:\New folder\train_short\1088_left.jpeg
# 85
# D:\New folder\train_short\1088_right.jpeg
# 86
# D:\New folder\train_short\108_left.jpeg
# 87
# D:\New folder\train_short\108_right.jpeg
# 88
# D:\New folder\train_short\1092_left.jpeg
# 89
# D:\New folder\train_short\1092_right.jpeg
# 90
# D:\New folder\train_short\1093_left.jpeg
# 91
# D:\New folder\train_short\1093_right.jpeg
# 92
# D:\New folder\train_short\1096_left.jpeg
# 93
# D:\New folder\train_short\1096_right.jpeg
# 94
# D:\New folder\train_short\1098_left.jpeg
# 95
# D:\New folder\train_short\1098_right.jpeg
# 96
# D:\New folder\train_short\1099_left.jpeg
# 97
# D:\New folder\train_short\1099_right.jpeg
# 98
# D:\New folder\train_short\10_left.jpeg
# 99
# D:\New folder\train_short\10_right.jpeg
# 100
# D:\New folder\train_short\1100_left.jpeg
# 101
# D:\New folder\train_short\1100_right.jpeg
# 102
# D:\New folder\train_short\1102_left.jpeg
# 103
# D:\New folder\train_short\1102_right.jpeg
# 104
# D:\New folder\train_short\1107_left.jpeg
# 105
# D:\New folder\train_short\1107_right.jpeg
# 106
# D:\New folder\train_short\1111_left.jpeg
# 107
# D:\New folder\train_short\1111_right.jpeg
# 108
# D:\New folder\train_short\1113_left.jpeg
# 109
# D:\New folder\train_short\1113_right.jpeg
# 110
# D:\New folder\train_short\1116_left.jpeg
# 111
# D:\New folder\train_short\1116_right.jpeg
# 112
# D:\New folder\train_short\1119_left.jpeg
# 113
# D:\New folder\train_short\1119_right.jpeg
# 114
# D:\New folder\train_short\111_left.jpeg
# 115
# D:\New folder\train_short\111_right.jpeg
# 116
# D:\New folder\train_short\1120_left.jpeg
# 117
# D:\New folder\train_short\1120_right.jpeg
# 118
# D:\New folder\train_short\1123_left.jpeg
# 119
# D:\New folder\train_short\1123_right.jpeg
# 120
# D:\New folder\train_short\1127_left.jpeg
# 121
# D:\New folder\train_short\1127_right.jpeg
# 122
# D:\New folder\train_short\1131_left.jpeg
# 123
# D:\New folder\train_short\1131_right.jpeg
# 124
# D:\New folder\train_short\1133_left.jpeg
# 125
# D:\New folder\train_short\1133_right.jpeg
# 126
# D:\New folder\train_short\1135_left.jpeg
# 127
# D:\New folder\train_short\1135_right.jpeg
# 128
# D:\New folder\train_short\1136_left.jpeg
# 129
# D:\New folder\train_short\1136_right.jpeg
# 130
# D:\New folder\train_short\1138_left.jpeg
# 131
# D:\New folder\train_short\1138_right.jpeg
# 132
# D:\New folder\train_short\1139_left.jpeg
# 133
# D:\New folder\train_short\1139_right.jpeg
# 134
# D:\New folder\train_short\1140_left.jpeg
# 135
# D:\New folder\train_short\1140_right.jpeg
# 136
# D:\New folder\train_short\1142_left.jpeg
# 137
# D:\New folder\train_short\1142_right.jpeg
# 138
# D:\New folder\train_short\1144_left.jpeg
# 139
# D:\New folder\train_short\1144_right.jpeg
# 140
# D:\New folder\train_short\1145_left.jpeg
# 141
# D:\New folder\train_short\1145_right.jpeg
# 142
# D:\New folder\train_short\1146_left.jpeg
# 143
# D:\New folder\train_short\1146_right.jpeg
# 144
# D:\New folder\train_short\1147_left.jpeg
# 145
# D:\New folder\train_short\1147_right.jpeg
# 146
# D:\New folder\train_short\114_left.jpeg
# 147
# D:\New folder\train_short\114_right.jpeg
# 148
# D:\New folder\train_short\1152_left.jpeg
# 149
# D:\New folder\train_short\1152_right.jpeg
# 150
# D:\New folder\train_short\115_left.jpeg
# 151
# D:\New folder\train_short\115_right.jpeg
# 152
# D:\New folder\train_short\1161_left.jpeg
# 153
# D:\New folder\train_short\1161_right.jpeg
# 154
# D:\New folder\train_short\1162_left.jpeg
# 155
# D:\New folder\train_short\1162_right.jpeg
# 156
# D:\New folder\train_short\1165_left.jpeg
# 157
# D:\New folder\train_short\1165_right.jpeg
# 158
# D:\New folder\train_short\1167_left.jpeg
# 159
# D:\New folder\train_short\1167_right.jpeg
# 160
# D:\New folder\train_short\1170_left.jpeg
# 161
# D:\New folder\train_short\1170_right.jpeg
# 162
# D:\New folder\train_short\1172_left.jpeg
# 163
# D:\New folder\train_short\1172_right.jpeg
# 164
# D:\New folder\train_short\1177_left.jpeg
# 165
# D:\New folder\train_short\1177_right.jpeg
# 166
# D:\New folder\train_short\1178_left.jpeg
# 167
# D:\New folder\train_short\1178_right.jpeg
# 168
# D:\New folder\train_short\1179_left.jpeg
# 169
# D:\New folder\train_short\1179_right.jpeg
# 170
# D:\New folder\train_short\117_left.jpeg
# 171
# D:\New folder\train_short\117_right.jpeg
# 172
# D:\New folder\train_short\1180_left.jpeg
# 173
# D:\New folder\train_short\1180_right.jpeg
# 174
# D:\New folder\train_short\1182_left.jpeg
# 175
# D:\New folder\train_short\1182_right.jpeg
# 176
# D:\New folder\train_short\1188_left.jpeg
# 177
# D:\New folder\train_short\1188_right.jpeg
# 178
# D:\New folder\train_short\1192_left.jpeg
# 179
# D:\New folder\train_short\1192_right.jpeg
# 180
# D:\New folder\train_short\1196_left.jpeg
# 181
# D:\New folder\train_short\1196_right.jpeg
# 182
# D:\New folder\train_short\1197_left.jpeg
# 183
# D:\New folder\train_short\1197_right.jpeg
# 184
# D:\New folder\train_short\1199_left.jpeg
# 185
# D:\New folder\train_short\1199_right.jpeg
# 186
# D:\New folder\train_short\119_left.jpeg
# 187
# D:\New folder\train_short\119_right.jpeg
# 188
# D:\New folder\train_short\1202_left.jpeg
# 189
# D:\New folder\train_short\1202_right.jpeg
# 190
# D:\New folder\train_short\1204_left.jpeg
# 191
# D:\New folder\train_short\1204_right.jpeg
# 192
# D:\New folder\train_short\1206_left.jpeg
# 193
# D:\New folder\train_short\1206_right.jpeg
# 194
# D:\New folder\train_short\1211_left.jpeg
# 195
# D:\New folder\train_short\1211_right.jpeg
# 196
# D:\New folder\train_short\1212_left.jpeg
# 197
# D:\New folder\train_short\1212_right.jpeg
# 198
# D:\New folder\train_short\1222_left.jpeg
# 199
# D:\New folder\train_short\1222_right.jpeg
# 200
# D:\New folder\train_short\1226_left.jpeg
# 201
# D:\New folder\train_short\1226_right.jpeg
# 202
# D:\New folder\train_short\1228_left.jpeg
# 203
# D:\New folder\train_short\1228_right.jpeg
# 204
# D:\New folder\train_short\122_left.jpeg
# 205
# D:\New folder\train_short\122_right.jpeg
# 206
# D:\New folder\train_short\1233_left.jpeg
# 207
# D:\New folder\train_short\1233_right.jpeg
# 208
# D:\New folder\train_short\1240_left.jpeg
# 209
# D:\New folder\train_short\1240_right.jpeg
# 210
# D:\New folder\train_short\1242_left.jpeg
# 211
# D:\New folder\train_short\1242_right.jpeg
# 212
# D:\New folder\train_short\1255_left.jpeg
# 213
# D:\New folder\train_short\1255_right.jpeg
# 214
# D:\New folder\train_short\1259_left.jpeg
# 215
# D:\New folder\train_short\1259_right.jpeg
# 216
# D:\New folder\train_short\125_left.jpeg
# 217
# D:\New folder\train_short\125_right.jpeg
# 218
# D:\New folder\train_short\1260_left.jpeg
# 219
# D:\New folder\train_short\1260_right.jpeg
# 220
# D:\New folder\train_short\1266_left.jpeg
# 221
# D:\New folder\train_short\1266_right.jpeg
# 222
# D:\New folder\train_short\1267_left.jpeg
# 223
# D:\New folder\train_short\1267_right.jpeg
# 224
# D:\New folder\train_short\1269_left.jpeg
# 225
# D:\New folder\train_short\1269_right.jpeg
# 226
# D:\New folder\train_short\1272_left.jpeg
# 227
# D:\New folder\train_short\1272_right.jpeg
# 228
# D:\New folder\train_short\1275_left.jpeg
# 229
# D:\New folder\train_short\1275_right.jpeg
# 230
# D:\New folder\train_short\1277_left.jpeg
# 231
# D:\New folder\train_short\1277_right.jpeg
# 232
# D:\New folder\train_short\1282_left.jpeg
# 233
# D:\New folder\train_short\1282_right.jpeg
# 234
# D:\New folder\train_short\1283_left.jpeg
# 235
# D:\New folder\train_short\1283_right.jpeg
# 236
# D:\New folder\train_short\1285_left.jpeg
# 237
# D:\New folder\train_short\1285_right.jpeg
# 238
# D:\New folder\train_short\1289_left.jpeg
# 239
# D:\New folder\train_short\1289_right.jpeg
# 240
# D:\New folder\train_short\1290_left.jpeg
# 241
# D:\New folder\train_short\1290_right.jpeg
# 242
# D:\New folder\train_short\1292_left.jpeg
# 243
# D:\New folder\train_short\1292_right.jpeg
# 244
# D:\New folder\train_short\1294_left.jpeg
# 245
# D:\New folder\train_short\1294_right.jpeg
# 246
# D:\New folder\train_short\1296_left.jpeg
# 247
# D:\New folder\train_short\1296_right.jpeg
# 248
# D:\New folder\train_short\1297_left.jpeg
# 249
# D:\New folder\train_short\1297_right.jpeg
# 250
# D:\New folder\train_short\1299_left.jpeg
# 251
# D:\New folder\train_short\1299_right.jpeg
# 252
# D:\New folder\train_short\129_left.jpeg
# 253
# D:\New folder\train_short\129_right.jpeg
# 254
# D:\New folder\train_short\1302_left.jpeg
# 255
# D:\New folder\train_short\1302_right.jpeg
# 256
# D:\New folder\train_short\1305_left.jpeg
# 257
# D:\New folder\train_short\1305_right.jpeg
# 258
# D:\New folder\train_short\1306_left.jpeg
# 259
# D:\New folder\train_short\1306_right.jpeg
# 260
# D:\New folder\train_short\1307_left.jpeg
# 261
# D:\New folder\train_short\1307_right.jpeg
# 262
# D:\New folder\train_short\1309_left.jpeg
# 263
# D:\New folder\train_short\1309_right.jpeg
# 264
# D:\New folder\train_short\1312_left.jpeg
# 265
# D:\New folder\train_short\1312_right.jpeg
# 266
# D:\New folder\train_short\1313_left.jpeg
# 267
# D:\New folder\train_short\1313_right.jpeg
# 268
# D:\New folder\train_short\1316_left.jpeg
# 269
# D:\New folder\train_short\1316_right.jpeg
# 270
# D:\New folder\train_short\1318_left.jpeg
# 271
# D:\New folder\train_short\1318_right.jpeg
# 272
# D:\New folder\train_short\1322_left.jpeg
# 273
# D:\New folder\train_short\1322_right.jpeg
# 274
# D:\New folder\train_short\1324_left.jpeg
# 275
# D:\New folder\train_short\1324_right.jpeg
# 276
# D:\New folder\train_short\1330_left.jpeg
# 277
# D:\New folder\train_short\1330_right.jpeg
# 278
# D:\New folder\train_short\1332_left.jpeg
# 279
# D:\New folder\train_short\1332_right.jpeg
# 280
# D:\New folder\train_short\1333_left.jpeg
# 281
# D:\New folder\train_short\1333_right.jpeg
# 282
# D:\New folder\train_short\1334_left.jpeg
# 283
# D:\New folder\train_short\1334_right.jpeg
# 284
# D:\New folder\train_short\1336_left.jpeg
# 285
# D:\New folder\train_short\1336_right.jpeg
# 286
# D:\New folder\train_short\1343_left.jpeg
# 287
# D:\New folder\train_short\1343_right.jpeg
# 288
# D:\New folder\train_short\1346_left.jpeg
# 289
# D:\New folder\train_short\1346_right.jpeg
# 290
# D:\New folder\train_short\1347_left.jpeg
# 291
# D:\New folder\train_short\1347_right.jpeg
# 292
# D:\New folder\train_short\1348_left.jpeg
# 293
# D:\New folder\train_short\1348_right.jpeg
# 294
# D:\New folder\train_short\1349_left.jpeg
# 295
# D:\New folder\train_short\1349_right.jpeg
# 296
# D:\New folder\train_short\1350_left.jpeg
# 297
# D:\New folder\train_short\1350_right.jpeg
# 298
# D:\New folder\train_short\1351_left.jpeg
# 299
# D:\New folder\train_short\1351_right.jpeg
# 300
# D:\New folder\train_short\1353_left.jpeg
# 301
# D:\New folder\train_short\1353_right.jpeg
# 302
# D:\New folder\train_short\1356_left.jpeg
# 303
# D:\New folder\train_short\1356_right.jpeg
# 304
# D:\New folder\train_short\1357_left.jpeg
# 305
# D:\New folder\train_short\1357_right.jpeg
# 306
# D:\New folder\train_short\1358_left.jpeg
# 307
# D:\New folder\train_short\1358_right.jpeg
# 308
# D:\New folder\train_short\1361_left.jpeg
# 309
# D:\New folder\train_short\1361_right.jpeg
# 310
# D:\New folder\train_short\1362_left.jpeg
# 311
# D:\New folder\train_short\1362_right.jpeg
# 312
# D:\New folder\train_short\1363_left.jpeg
# 313
# D:\New folder\train_short\1363_right.jpeg
# 314
# D:\New folder\train_short\1367_left.jpeg
# 315
# D:\New folder\train_short\1367_right.jpeg
# 316
# D:\New folder\train_short\1369_left.jpeg
# 317
# D:\New folder\train_short\1369_right.jpeg
# 318
# D:\New folder\train_short\1370_left.jpeg
# 319
# D:\New folder\train_short\1370_right.jpeg
# 320
# D:\New folder\train_short\1373_left.jpeg
# 321
# D:\New folder\train_short\1373_right.jpeg
# 322
# D:\New folder\train_short\1374_left.jpeg
# 323
# D:\New folder\train_short\1374_right.jpeg
# 324
# D:\New folder\train_short\1377_left.jpeg
# 325
# D:\New folder\train_short\1377_right.jpeg
# 326
# D:\New folder\train_short\1378_left.jpeg
# 327
# D:\New folder\train_short\1378_right.jpeg
# 328
# D:\New folder\train_short\1387_left.jpeg
# 329
# D:\New folder\train_short\1387_right.jpeg
# 330
# D:\New folder\train_short\1388_left.jpeg
# 331
# D:\New folder\train_short\1388_right.jpeg
# 332
# D:\New folder\train_short\1391_left.jpeg
# 333
# D:\New folder\train_short\1391_right.jpeg
# 334
# D:\New folder\train_short\1393_left.jpeg
# 335
# D:\New folder\train_short\1393_right.jpeg
# 336
# D:\New folder\train_short\1394_left.jpeg
# 337
# D:\New folder\train_short\1394_right.jpeg
# 338
# D:\New folder\train_short\1395_left.jpeg
# 339
# D:\New folder\train_short\1395_right.jpeg
# 340
# D:\New folder\train_short\1396_left.jpeg
# 341
# D:\New folder\train_short\1396_right.jpeg
# 342
# D:\New folder\train_short\1399_left.jpeg
# 343
# D:\New folder\train_short\1399_right.jpeg
# 344
# D:\New folder\train_short\13_left.jpeg
# 345
# D:\New folder\train_short\13_right.jpeg
# 346
# D:\New folder\train_short\1407_left.jpeg
# 347
# D:\New folder\train_short\1407_right.jpeg
# 348
# D:\New folder\train_short\1408_left.jpeg
# 349
# D:\New folder\train_short\1408_right.jpeg
# 350
# D:\New folder\train_short\1409_left.jpeg
# 351
# D:\New folder\train_short\1409_right.jpeg
# 352
# D:\New folder\train_short\140_left.jpeg
# 353
# D:\New folder\train_short\140_right.jpeg
# 354
# D:\New folder\train_short\1411_left.jpeg
# 355
# D:\New folder\train_short\1411_right.jpeg
# 356
# D:\New folder\train_short\1412_left.jpeg
# 357
# D:\New folder\train_short\1412_right.jpeg
# 358
# D:\New folder\train_short\1418_left.jpeg
# 359
# D:\New folder\train_short\1418_right.jpeg
# 360
# D:\New folder\train_short\1419_left.jpeg
# 361
# D:\New folder\train_short\1419_right.jpeg
# 362
# D:\New folder\train_short\1420_left.jpeg
# 363
# D:\New folder\train_short\1420_right.jpeg
# 364
# D:\New folder\train_short\1422_left.jpeg
# 365
# D:\New folder\train_short\1422_right.jpeg
# 366
# D:\New folder\train_short\1424_left.jpeg
# 367
# D:\New folder\train_short\1424_right.jpeg
# 368
# D:\New folder\train_short\1425_left.jpeg
# 369
# D:\New folder\train_short\1425_right.jpeg
# 370
# D:\New folder\train_short\1427_left.jpeg
# 371
# D:\New folder\train_short\1427_right.jpeg
# 372
# D:\New folder\train_short\1429_left.jpeg
# 373
# D:\New folder\train_short\1429_right.jpeg
# 374
# D:\New folder\train_short\1430_left.jpeg
# 375
# D:\New folder\train_short\1430_right.jpeg
# 376
# D:\New folder\train_short\1431_left.jpeg
# 377
# D:\New folder\train_short\1431_right.jpeg
# 378
# D:\New folder\train_short\1432_left.jpeg
# 379
# D:\New folder\train_short\1432_right.jpeg
# 380
# D:\New folder\train_short\1439_left.jpeg
# 381
# D:\New folder\train_short\1439_right.jpeg
# 382
# D:\New folder\train_short\1444_left.jpeg
# 383
# D:\New folder\train_short\1444_right.jpeg
# 384
# D:\New folder\train_short\1446_left.jpeg
# 385
# D:\New folder\train_short\1446_right.jpeg
# 386
# D:\New folder\train_short\1449_left.jpeg
# 387
# D:\New folder\train_short\1449_right.jpeg
# 388
# D:\New folder\train_short\1452_left.jpeg
# 389
# D:\New folder\train_short\1452_right.jpeg
# 390
# D:\New folder\train_short\1454_left.jpeg
# 391
# D:\New folder\train_short\1454_right.jpeg
# 392
# D:\New folder\train_short\145_left.jpeg
# 393
# D:\New folder\train_short\145_right.jpeg
# 394
# D:\New folder\train_short\1469_left.jpeg
# 395
# D:\New folder\train_short\1469_right.jpeg
# 396
# D:\New folder\train_short\1471_left.jpeg
# 397
# D:\New folder\train_short\1471_right.jpeg
# 398
# D:\New folder\train_short\1475_left.jpeg
# 399
# D:\New folder\train_short\1475_right.jpeg
# 400
# D:\New folder\train_short\1478_left.jpeg
# 401
# D:\New folder\train_short\1478_right.jpeg
# 402
# D:\New folder\train_short\1480_left.jpeg
# 403
# D:\New folder\train_short\1480_right.jpeg
# 404
# D:\New folder\train_short\1481_left.jpeg
# 405
# D:\New folder\train_short\1481_right.jpeg
# 406
# D:\New folder\train_short\1487_left.jpeg
# 407
# D:\New folder\train_short\1487_right.jpeg
# 408
# D:\New folder\train_short\1488_left.jpeg
# 409
# D:\New folder\train_short\1488_right.jpeg
# 410
# D:\New folder\train_short\1492_left.jpeg
# 411
# D:\New folder\train_short\1492_right.jpeg
# 412
# D:\New folder\train_short\1493_left.jpeg
# 413
# D:\New folder\train_short\1493_right.jpeg
# 414
# D:\New folder\train_short\1495_left.jpeg
# 415
# D:\New folder\train_short\1495_right.jpeg
# 416
# D:\New folder\train_short\1496_left.jpeg
# 417
# D:\New folder\train_short\1496_right.jpeg
# 418
# D:\New folder\train_short\1497_left.jpeg
# 419
# D:\New folder\train_short\1497_right.jpeg
# 420
# D:\New folder\train_short\1499_left.jpeg
# 421
# D:\New folder\train_short\1499_right.jpeg
# 422
# D:\New folder\train_short\149_left.jpeg
# 423
# D:\New folder\train_short\149_right.jpeg
# 424
# D:\New folder\train_short\1500_left.jpeg
# 425
# D:\New folder\train_short\1500_right.jpeg
# 426
# D:\New folder\train_short\1501_left.jpeg
# 427
# D:\New folder\train_short\1501_right.jpeg
# 428
# D:\New folder\train_short\1502_left.jpeg
# 429
# D:\New folder\train_short\1502_right.jpeg
# 430
# D:\New folder\train_short\1504_left.jpeg
# 431
# D:\New folder\train_short\1504_right.jpeg
# 432
# D:\New folder\train_short\1505_left.jpeg
# 433
# D:\New folder\train_short\1505_right.jpeg
# 434
# D:\New folder\train_short\1506_left.jpeg
# 435
# D:\New folder\train_short\1506_right.jpeg
# 436
# D:\New folder\train_short\1507_left.jpeg
# 437
# D:\New folder\train_short\1507_right.jpeg
# 438
# D:\New folder\train_short\1508_left.jpeg
# 439
# D:\New folder\train_short\1508_right.jpeg
# 440
# D:\New folder\train_short\1509_left.jpeg
# 441
# D:\New folder\train_short\1509_right.jpeg
# 442
# D:\New folder\train_short\1513_left.jpeg
# 443
# D:\New folder\train_short\1513_right.jpeg
# 444
# D:\New folder\train_short\1514_left.jpeg
# 445
# D:\New folder\train_short\1514_right.jpeg
# 446
# D:\New folder\train_short\1516_left.jpeg
# 447
# D:\New folder\train_short\1516_right.jpeg
# 448
# D:\New folder\train_short\1520_left.jpeg
# 449
# D:\New folder\train_short\1520_right.jpeg
# 450
# D:\New folder\train_short\1524_left.jpeg
# 451
# D:\New folder\train_short\1524_right.jpeg
# 452
# D:\New folder\train_short\1526_left.jpeg
# 453
# D:\New folder\train_short\1526_right.jpeg
# 454
# D:\New folder\train_short\1527_left.jpeg
# 455
# D:\New folder\train_short\1527_right.jpeg
# 456
# D:\New folder\train_short\1528_left.jpeg
# 457
# D:\New folder\train_short\1528_right.jpeg
# 458
# D:\New folder\train_short\1530_left.jpeg
# 459
# D:\New folder\train_short\1530_right.jpeg
# 460
# D:\New folder\train_short\1532_left.jpeg
# 461
# D:\New folder\train_short\1532_right.jpeg
# 462
# D:\New folder\train_short\1536_left.jpeg
# 463
# D:\New folder\train_short\1536_right.jpeg
# 464
# D:\New folder\train_short\1540_left.jpeg
# 465
# D:\New folder\train_short\1540_right.jpeg
# 466
# D:\New folder\train_short\1541_left.jpeg
# 467
# D:\New folder\train_short\1541_right.jpeg
# 468
# D:\New folder\train_short\1544_left.jpeg
# 469
# D:\New folder\train_short\1544_right.jpeg
# 470
# D:\New folder\train_short\1550_left.jpeg
# 471
# D:\New folder\train_short\1550_right.jpeg
# 472
# D:\New folder\train_short\1551_left.jpeg
# 473
# D:\New folder\train_short\1551_right.jpeg
# 474
# D:\New folder\train_short\1552_left.jpeg
# 475
# D:\New folder\train_short\1552_right.jpeg
# 476
# D:\New folder\train_short\1557_left.jpeg
# 477
# D:\New folder\train_short\1557_right.jpeg
# 478
# D:\New folder\train_short\155_left.jpeg
# 479
# D:\New folder\train_short\155_right.jpeg
# 480
# D:\New folder\train_short\1563_left.jpeg
# 481
# D:\New folder\train_short\1563_right.jpeg
# 482
# D:\New folder\train_short\1569_left.jpeg
# 483
# D:\New folder\train_short\1569_right.jpeg
# 484
# D:\New folder\train_short\156_left.jpeg
# 485
# D:\New folder\train_short\156_right.jpeg
# 486
# D:\New folder\train_short\1570_left.jpeg
# 487
# D:\New folder\train_short\1570_right.jpeg
# 488
# D:\New folder\train_short\1574_left.jpeg
# 489
# D:\New folder\train_short\1574_right.jpeg
# 490
# D:\New folder\train_short\1579_left.jpeg
# 491
# D:\New folder\train_short\1579_right.jpeg
# 492
# D:\New folder\train_short\157_left.jpeg
# 493
# D:\New folder\train_short\157_right.jpeg
# 494
# D:\New folder\train_short\1586_left.jpeg
# 495
# D:\New folder\train_short\1586_right.jpeg
# 496
# D:\New folder\train_short\1588_left.jpeg
# 497
# D:\New folder\train_short\1588_right.jpeg
# 498
# D:\New folder\train_short\1589_left.jpeg
# 499
# D:\New folder\train_short\1589_right.jpeg
# 500
# D:\New folder\train_short\1592_left.jpeg
# 501
# D:\New folder\train_short\1592_right.jpeg
# 502
# D:\New folder\train_short\1595_left.jpeg
# 503
# D:\New folder\train_short\1595_right.jpeg
# 504
# D:\New folder\train_short\1596_left.jpeg
# 505
# D:\New folder\train_short\1596_right.jpeg
# 506
# D:\New folder\train_short\1599_left.jpeg
# 507
# D:\New folder\train_short\1599_right.jpeg
# 508
# D:\New folder\train_short\159_left.jpeg
# 509
# D:\New folder\train_short\159_right.jpeg
# 510
# D:\New folder\train_short\15_left.jpeg
# 511
# D:\New folder\train_short\15_right.jpeg
# 512
# D:\New folder\train_short\1600_left.jpeg
# 513
# D:\New folder\train_short\1600_right.jpeg
# 514
# D:\New folder\train_short\1607_left.jpeg
# 515
# D:\New folder\train_short\1607_right.jpeg
# 516
# D:\New folder\train_short\1608_left.jpeg
# 517
# D:\New folder\train_short\1608_right.jpeg
# 518
# D:\New folder\train_short\1609_left.jpeg
# 519
# D:\New folder\train_short\1609_right.jpeg
# 520
# D:\New folder\train_short\1610_left.jpeg
# 521
# D:\New folder\train_short\1610_right.jpeg
# 522
# D:\New folder\train_short\1611_left.jpeg
# 523
# D:\New folder\train_short\1611_right.jpeg
# 524
# D:\New folder\train_short\1614_left.jpeg
# 525
# D:\New folder\train_short\1614_right.jpeg
# 526
# D:\New folder\train_short\161_left.jpeg
# 527
# D:\New folder\train_short\161_right.jpeg
# 528
# D:\New folder\train_short\1624_left.jpeg
# 529
# D:\New folder\train_short\1624_right.jpeg
# 530
# D:\New folder\train_short\162_left.jpeg
# 531
# D:\New folder\train_short\162_right.jpeg
# 532
# D:\New folder\train_short\1630_left.jpeg
# 533
# D:\New folder\train_short\1630_right.jpeg
# 534
# D:\New folder\train_short\1632_left.jpeg
# 535
# D:\New folder\train_short\1632_right.jpeg
# 536
# D:\New folder\train_short\1634_left.jpeg
# 537
# D:\New folder\train_short\1634_right.jpeg
# 538
# D:\New folder\train_short\1636_left.jpeg
# 539
# D:\New folder\train_short\1636_right.jpeg
# 540
# D:\New folder\train_short\1638_left.jpeg
# 541
# D:\New folder\train_short\1638_right.jpeg
# 542
# D:\New folder\train_short\1639_left.jpeg
# 543
# D:\New folder\train_short\1639_right.jpeg
# 544
# D:\New folder\train_short\163_left.jpeg
# 545
# D:\New folder\train_short\163_right.jpeg
# 546
# D:\New folder\train_short\1640_left.jpeg
# 547
# D:\New folder\train_short\1640_right.jpeg
# 548
# D:\New folder\train_short\1641_left.jpeg
# 549
# D:\New folder\train_short\1641_right.jpeg
# 550
# D:\New folder\train_short\1643_left.jpeg
# 551
# D:\New folder\train_short\1643_right.jpeg
# 552
# D:\New folder\train_short\1649_left.jpeg
# 553
# D:\New folder\train_short\1649_right.jpeg
# 554
# D:\New folder\train_short\164_left.jpeg
# 555
# D:\New folder\train_short\164_right.jpeg
# 556
# D:\New folder\train_short\1650_left.jpeg
# 557
# D:\New folder\train_short\1650_right.jpeg
# 558
# D:\New folder\train_short\1651_left.jpeg
# 559
# D:\New folder\train_short\1651_right.jpeg
# 560
# D:\New folder\train_short\1655_left.jpeg
# 561
# D:\New folder\train_short\1655_right.jpeg
# 562
# D:\New folder\train_short\1658_left.jpeg
# 563
# D:\New folder\train_short\1658_right.jpeg
# 564
# D:\New folder\train_short\1659_left.jpeg
# 565
# D:\New folder\train_short\1659_right.jpeg
# 566
# D:\New folder\train_short\1660_left.jpeg
# 567
# D:\New folder\train_short\1660_right.jpeg
# 568
# D:\New folder\train_short\1663_left.jpeg
# 569
# D:\New folder\train_short\1663_right.jpeg
# 570
# D:\New folder\train_short\1666_left.jpeg
# 571
# D:\New folder\train_short\1666_right.jpeg
# 572
# D:\New folder\train_short\1667_left.jpeg
# 573
# D:\New folder\train_short\1667_right.jpeg
# 574
# D:\New folder\train_short\1669_left.jpeg
# 575
# D:\New folder\train_short\1669_right.jpeg
# 576
# D:\New folder\train_short\1672_left.jpeg
# 577
# D:\New folder\train_short\1672_right.jpeg
# 578
# D:\New folder\train_short\1673_left.jpeg
# 579
# D:\New folder\train_short\1673_right.jpeg
# 580
# D:\New folder\train_short\1674_left.jpeg
# 581
# D:\New folder\train_short\1674_right.jpeg
# 582
# D:\New folder\train_short\1675_left.jpeg
# 583
# D:\New folder\train_short\1675_right.jpeg
# 584
# D:\New folder\train_short\1678_left.jpeg
# 585
# D:\New folder\train_short\1678_right.jpeg
# 586
# D:\New folder\train_short\167_left.jpeg
# 587
# D:\New folder\train_short\167_right.jpeg
# 588
# D:\New folder\train_short\1680_left.jpeg
# 589
# D:\New folder\train_short\1680_right.jpeg
# 590
# D:\New folder\train_short\1687_left.jpeg
# 591
# D:\New folder\train_short\1687_right.jpeg
# 592
# D:\New folder\train_short\1688_left.jpeg
# 593
# D:\New folder\train_short\1688_right.jpeg
# 594
# D:\New folder\train_short\1689_left.jpeg
# 595
# D:\New folder\train_short\1689_right.jpeg
# 596
# D:\New folder\train_short\1696_left.jpeg
# 597
# D:\New folder\train_short\1696_right.jpeg
# 598
# D:\New folder\train_short\1698_left.jpeg
# 599
# D:\New folder\train_short\1698_right.jpeg
# 600
# D:\New folder\train_short\169_left.jpeg
# 601
# D:\New folder\train_short\169_right.jpeg
# 602
# D:\New folder\train_short\16_left.jpeg
# 603
# D:\New folder\train_short\16_right.jpeg
# 604
# D:\New folder\train_short\1702_left.jpeg
# 605
# D:\New folder\train_short\1702_right.jpeg
# 606
# D:\New folder\train_short\1706_left.jpeg
# 607
# D:\New folder\train_short\1706_right.jpeg
# 608
# D:\New folder\train_short\170_left.jpeg
# 609
# D:\New folder\train_short\170_right.jpeg
# 610
# D:\New folder\train_short\1710_left.jpeg
# 611
# D:\New folder\train_short\1710_right.jpeg
# 612
# D:\New folder\train_short\1713_left.jpeg
# 613
# D:\New folder\train_short\1713_right.jpeg
# 614
# D:\New folder\train_short\1718_left.jpeg
# 615
# D:\New folder\train_short\1718_right.jpeg
# 616
# D:\New folder\train_short\1719_left.jpeg
# 617
# D:\New folder\train_short\1719_right.jpeg
# 618
# D:\New folder\train_short\1722_left.jpeg
# 619
# D:\New folder\train_short\1722_right.jpeg
# 620
# D:\New folder\train_short\1724_left.jpeg
# 621
# D:\New folder\train_short\1724_right.jpeg
# 622
# D:\New folder\train_short\1727_left.jpeg
# 623
# D:\New folder\train_short\1727_right.jpeg
# 624
# D:\New folder\train_short\172_left.jpeg
# 625
# D:\New folder\train_short\172_right.jpeg
# 626
# D:\New folder\train_short\1732_left.jpeg
# 627
# D:\New folder\train_short\1732_right.jpeg
# 628
# D:\New folder\train_short\1733_left.jpeg
# 629
# D:\New folder\train_short\1733_right.jpeg
# 630
# D:\New folder\train_short\1736_left.jpeg
# 631
# D:\New folder\train_short\1736_right.jpeg
# 632
# D:\New folder\train_short\1737_left.jpeg
# 633
# D:\New folder\train_short\1737_right.jpeg
# 634
# D:\New folder\train_short\1741_left.jpeg
# 635
# D:\New folder\train_short\1741_right.jpeg
# 636
# D:\New folder\train_short\1742_left.jpeg
# 637
# D:\New folder\train_short\1742_right.jpeg
# 638
# D:\New folder\train_short\1743_left.jpeg
# 639
# D:\New folder\train_short\1743_right.jpeg
# 640
# D:\New folder\train_short\1744_left.jpeg
# 641
# D:\New folder\train_short\1744_right.jpeg
# 642
# D:\New folder\train_short\1749_left.jpeg
# 643
# D:\New folder\train_short\1749_right.jpeg
# 644
# D:\New folder\train_short\174_left.jpeg
# 645
# D:\New folder\train_short\174_right.jpeg
# 646
# D:\New folder\train_short\1751_left.jpeg
# 647
# D:\New folder\train_short\1751_right.jpeg
# 648
# D:\New folder\train_short\1752_left.jpeg
# 649
# D:\New folder\train_short\1752_right.jpeg
# 650
# D:\New folder\train_short\1754_left.jpeg
# 651
# D:\New folder\train_short\1754_right.jpeg
# 652
# D:\New folder\train_short\1756_left.jpeg
# 653
# D:\New folder\train_short\1756_right.jpeg
# 654
# D:\New folder\train_short\1759_left.jpeg
# 655
# D:\New folder\train_short\1759_right.jpeg
# 656
# D:\New folder\train_short\1763_left.jpeg
# 657
# D:\New folder\train_short\1763_right.jpeg
# 658
# D:\New folder\train_short\1764_left.jpeg
# 659
# D:\New folder\train_short\1764_right.jpeg
# 660
# D:\New folder\train_short\1765_left.jpeg
# 661
# D:\New folder\train_short\1765_right.jpeg
# 662
# D:\New folder\train_short\1766_left.jpeg
# 663
# D:\New folder\train_short\1766_right.jpeg
# 664
# D:\New folder\train_short\1769_left.jpeg
# 665
# D:\New folder\train_short\1769_right.jpeg
# 666
# D:\New folder\train_short\1771_left.jpeg
# 667
# D:\New folder\train_short\1771_right.jpeg
# 668
# D:\New folder\train_short\1772_left.jpeg
# 669
# D:\New folder\train_short\1772_right.jpeg
# 670
# D:\New folder\train_short\1775_left.jpeg
# 671
# D:\New folder\train_short\1775_right.jpeg
# 672
# D:\New folder\train_short\1776_left.jpeg
# 673
# D:\New folder\train_short\1776_right.jpeg
# 674
# D:\New folder\train_short\1777_left.jpeg
# 675
# D:\New folder\train_short\1777_right.jpeg
# 676
# D:\New folder\train_short\1779_left.jpeg
# 677
# D:\New folder\train_short\1779_right.jpeg
# 678
# D:\New folder\train_short\177_left.jpeg
# 679
# D:\New folder\train_short\177_right.jpeg
# 680
# D:\New folder\train_short\1785_left.jpeg
# 681
# D:\New folder\train_short\1785_right.jpeg
# 682
# D:\New folder\train_short\1786_left.jpeg
# 683
# D:\New folder\train_short\1786_right.jpeg
# 684
# D:\New folder\train_short\178_left.jpeg
# 685
# D:\New folder\train_short\178_right.jpeg
# 686
# D:\New folder\train_short\1793_left.jpeg
# 687
# D:\New folder\train_short\1793_right.jpeg
# 688
# D:\New folder\train_short\1799_left.jpeg
# 689
# D:\New folder\train_short\1799_right.jpeg
# 690
# D:\New folder\train_short\179_left.jpeg
# 691
# D:\New folder\train_short\179_right.jpeg
# 692
# D:\New folder\train_short\17_left.jpeg
# 693
# D:\New folder\train_short\17_right.jpeg
# 694
# D:\New folder\train_short\1801_left.jpeg
# 695
# D:\New folder\train_short\1801_right.jpeg
# 696
# D:\New folder\train_short\1802_left.jpeg
# 697
# D:\New folder\train_short\1802_right.jpeg
# 698
# D:\New folder\train_short\1803_left.jpeg
# 699
# D:\New folder\train_short\1803_right.jpeg
# 700
# D:\New folder\train_short\1808_left.jpeg
# 701
# D:\New folder\train_short\1808_right.jpeg
# 702
# D:\New folder\train_short\1810_left.jpeg
# 703
# D:\New folder\train_short\1810_right.jpeg
# 704
# D:\New folder\train_short\1817_left.jpeg
# 705
# D:\New folder\train_short\1817_right.jpeg
# 706
# D:\New folder\train_short\1823_left.jpeg
# 707
# D:\New folder\train_short\1823_right.jpeg
# 708
# D:\New folder\train_short\1826_left.jpeg
# 709
# D:\New folder\train_short\1826_right.jpeg
# 710
# D:\New folder\train_short\1827_left.jpeg
# 711
# D:\New folder\train_short\1827_right.jpeg
# 712
# D:\New folder\train_short\1831_left.jpeg
# 713
# D:\New folder\train_short\1831_right.jpeg
# 714
# D:\New folder\train_short\1832_left.jpeg
# 715
# D:\New folder\train_short\1832_right.jpeg
# 716
# D:\New folder\train_short\1833_left.jpeg
# 717
# D:\New folder\train_short\1833_right.jpeg
# 718
# D:\New folder\train_short\1835_left.jpeg
# 719
# D:\New folder\train_short\1835_right.jpeg
# 720
# D:\New folder\train_short\1836_left.jpeg
# 721
# D:\New folder\train_short\1836_right.jpeg
# 722
# D:\New folder\train_short\1839_left.jpeg
# 723
# D:\New folder\train_short\1839_right.jpeg
# 724
# D:\New folder\train_short\1847_left.jpeg
# 725
# D:\New folder\train_short\1847_right.jpeg
# 726
# D:\New folder\train_short\1849_left.jpeg
# 727
# D:\New folder\train_short\1849_right.jpeg
# 728
# D:\New folder\train_short\184_left.jpeg
# 729
# D:\New folder\train_short\184_right.jpeg
# 730
# D:\New folder\train_short\1851_left.jpeg
# 731
# D:\New folder\train_short\1851_right.jpeg
# 732
# D:\New folder\train_short\1853_left.jpeg
# 733
# D:\New folder\train_short\1853_right.jpeg
# 734
# D:\New folder\train_short\1855_left.jpeg
# 735
# D:\New folder\train_short\1855_right.jpeg
# 736
# D:\New folder\train_short\1856_left.jpeg
# 737
# D:\New folder\train_short\1856_right.jpeg
# 738
# D:\New folder\train_short\1859_left.jpeg
# 739
# D:\New folder\train_short\1859_right.jpeg
# 740
# D:\New folder\train_short\1862_left.jpeg
# 741
# D:\New folder\train_short\1862_right.jpeg
# 742
# D:\New folder\train_short\1867_left.jpeg
# 743
# D:\New folder\train_short\1867_right.jpeg
# 744
# D:\New folder\train_short\1868_left.jpeg
# 745
# D:\New folder\train_short\1868_right.jpeg
# 746
# D:\New folder\train_short\1869_left.jpeg
# 747
# D:\New folder\train_short\1869_right.jpeg
# 748
# D:\New folder\train_short\186_left.jpeg
# 749
# D:\New folder\train_short\186_right.jpeg
# 750
# D:\New folder\train_short\1872_left.jpeg
# 751
# D:\New folder\train_short\1872_right.jpeg
# 752
# D:\New folder\train_short\1873_left.jpeg
# 753
# D:\New folder\train_short\1873_right.jpeg
# 754
# D:\New folder\train_short\1878_left.jpeg
# 755
# D:\New folder\train_short\1878_right.jpeg
# 756
# D:\New folder\train_short\1880_left.jpeg
# 757
# D:\New folder\train_short\1880_right.jpeg
# 758
# D:\New folder\train_short\1881_left.jpeg
# 759
# D:\New folder\train_short\1881_right.jpeg
# 760
# D:\New folder\train_short\1886_left.jpeg
# 761
# D:\New folder\train_short\1886_right.jpeg
# 762
# D:\New folder\train_short\1887_left.jpeg
# 763
# D:\New folder\train_short\1887_right.jpeg
# 764
# D:\New folder\train_short\1889_left.jpeg
# 765
# D:\New folder\train_short\1889_right.jpeg
# 766
# D:\New folder\train_short\1893_left.jpeg
# 767
# D:\New folder\train_short\1893_right.jpeg
# 768
# D:\New folder\train_short\1905_left.jpeg
# 769
# D:\New folder\train_short\1905_right.jpeg
# 770
# D:\New folder\train_short\1906_left.jpeg
# 771
# D:\New folder\train_short\1906_right.jpeg
# 772
# D:\New folder\train_short\1907_left.jpeg
# 773
# D:\New folder\train_short\1907_right.jpeg
# 774
# D:\New folder\train_short\190_left.jpeg
# 775
# D:\New folder\train_short\190_right.jpeg
# 776
# D:\New folder\train_short\1910_left.jpeg
# 777
# D:\New folder\train_short\1910_right.jpeg
# 778
# D:\New folder\train_short\1914_left.jpeg
# 779
# D:\New folder\train_short\1914_right.jpeg
# 780
# D:\New folder\train_short\1915_left.jpeg
# 781
# D:\New folder\train_short\1915_right.jpeg
# 782
# D:\New folder\train_short\1916_left.jpeg
# 783
# D:\New folder\train_short\1916_right.jpeg
# 784
# D:\New folder\train_short\1919_left.jpeg
# 785
# D:\New folder\train_short\1919_right.jpeg
# 786
# D:\New folder\train_short\1920_left.jpeg
# 787
# D:\New folder\train_short\1920_right.jpeg
# 788
# D:\New folder\train_short\1926_left.jpeg
# 789
# D:\New folder\train_short\1926_right.jpeg
# 790
# D:\New folder\train_short\1928_left.jpeg
# 791
# D:\New folder\train_short\1928_right.jpeg
# 792
# D:\New folder\train_short\1929_left.jpeg
# 793
# D:\New folder\train_short\1929_right.jpeg
# 794
# D:\New folder\train_short\192_left.jpeg
# 795
# D:\New folder\train_short\192_right.jpeg
# 796
# D:\New folder\train_short\1932_left.jpeg
# 797
# D:\New folder\train_short\1932_right.jpeg
# 798
# D:\New folder\train_short\1933_left.jpeg
# 799
# D:\New folder\train_short\1933_right.jpeg
# 800
# D:\New folder\train_short\1936_left.jpeg
# 801
# D:\New folder\train_short\1936_right.jpeg
# 802
# D:\New folder\train_short\1940_left.jpeg
# 803
# D:\New folder\train_short\1940_right.jpeg
# 804
# D:\New folder\train_short\1941_left.jpeg
# 805
# D:\New folder\train_short\1941_right.jpeg
# 806
# D:\New folder\train_short\1943_left.jpeg
# 807
# D:\New folder\train_short\1943_right.jpeg
# 808
# D:\New folder\train_short\1947_left.jpeg
# 809
# D:\New folder\train_short\1947_right.jpeg
# 810
# D:\New folder\train_short\194_left.jpeg
# 811
# D:\New folder\train_short\194_right.jpeg
# 812
# D:\New folder\train_short\1953_left.jpeg
# 813
# D:\New folder\train_short\1953_right.jpeg
# 814
# D:\New folder\train_short\1955_left.jpeg
# 815
# D:\New folder\train_short\1955_right.jpeg
# 816
# D:\New folder\train_short\1959_left.jpeg
# 817
# D:\New folder\train_short\1959_right.jpeg
# 818
# D:\New folder\train_short\195_left.jpeg
# 819
# D:\New folder\train_short\195_right.jpeg
# 820
# D:\New folder\train_short\1960_left.jpeg
# 821
# D:\New folder\train_short\1960_right.jpeg
# 822
# D:\New folder\train_short\1965_left.jpeg
# 823
# D:\New folder\train_short\1965_right.jpeg
# 824
# D:\New folder\train_short\1967_left.jpeg
# 825
# D:\New folder\train_short\1967_right.jpeg
# 826
# D:\New folder\train_short\1971_left.jpeg
# 827
# D:\New folder\train_short\1971_right.jpeg
# 828
# D:\New folder\train_short\1972_left.jpeg
# 829
# D:\New folder\train_short\1972_right.jpeg
# 830
# D:\New folder\train_short\1974_left.jpeg
# 831
# D:\New folder\train_short\1974_right.jpeg
# 832
# D:\New folder\train_short\1977_left.jpeg
# 833
# D:\New folder\train_short\1977_right.jpeg
# 834
# D:\New folder\train_short\197_left.jpeg
# 835
# D:\New folder\train_short\197_right.jpeg
# 836
# D:\New folder\train_short\1981_left.jpeg
# 837
# D:\New folder\train_short\1981_right.jpeg
# 838
# D:\New folder\train_short\1982_left.jpeg
# 839
# D:\New folder\train_short\1982_right.jpeg
# 840
# D:\New folder\train_short\1985_left.jpeg
# 841
# D:\New folder\train_short\1985_right.jpeg
# 842
# D:\New folder\train_short\1986_left.jpeg
# 843
# D:\New folder\train_short\1986_right.jpeg
# 844
# D:\New folder\train_short\1987_left.jpeg
# 845
# D:\New folder\train_short\1987_right.jpeg
# 846
# D:\New folder\train_short\1988_left.jpeg
# 847
# D:\New folder\train_short\1988_right.jpeg
# 848
# D:\New folder\train_short\1991_left.jpeg
# 849
# D:\New folder\train_short\1991_right.jpeg
# 850
# D:\New folder\train_short\1997_left.jpeg
# 851
# D:\New folder\train_short\1997_right.jpeg
# 852
# D:\New folder\train_short\1999_left.jpeg
# 853
# D:\New folder\train_short\1999_right.jpeg
# 854
# D:\New folder\train_short\199_left.jpeg
# 855
# D:\New folder\train_short\199_right.jpeg
# 856
# D:\New folder\train_short\19_left.jpeg
# 857
# D:\New folder\train_short\19_right.jpeg
# 858
# D:\New folder\train_short\2000_left.jpeg
# 859
# D:\New folder\train_short\2000_right.jpeg
# 860
# D:\New folder\train_short\2001_left.jpeg
# 861
# D:\New folder\train_short\2001_right.jpeg
# 862
# D:\New folder\train_short\2007_left.jpeg
# 863
# D:\New folder\train_short\2007_right.jpeg
# 864
# D:\New folder\train_short\2008_left.jpeg
# 865
# D:\New folder\train_short\2008_right.jpeg
# 866
# D:\New folder\train_short\2010_left.jpeg
# 867
# D:\New folder\train_short\2010_right.jpeg
# 868
# D:\New folder\train_short\2011_left.jpeg
# 869
# D:\New folder\train_short\2011_right.jpeg
# 870
# D:\New folder\train_short\2014_left.jpeg
# 871
# D:\New folder\train_short\2014_right.jpeg
# 872
# D:\New folder\train_short\2015_left.jpeg
# 873
# D:\New folder\train_short\2015_right.jpeg
# 874
# D:\New folder\train_short\2016_left.jpeg
# 875
# D:\New folder\train_short\2016_right.jpeg
# 876
# D:\New folder\train_short\2029_left.jpeg
# 877
# D:\New folder\train_short\2029_right.jpeg
# 878
# D:\New folder\train_short\2030_left.jpeg
# 879
# D:\New folder\train_short\2030_right.jpeg
# 880
# D:\New folder\train_short\2031_left.jpeg
# 881
# D:\New folder\train_short\2031_right.jpeg
# 882
# D:\New folder\train_short\2034_left.jpeg
# 883
# D:\New folder\train_short\2034_right.jpeg
# 884
# D:\New folder\train_short\2035_left.jpeg
# 885
# D:\New folder\train_short\2035_right.jpeg
# 886
# D:\New folder\train_short\2036_left.jpeg
# 887
# D:\New folder\train_short\2036_right.jpeg
# 888
# D:\New folder\train_short\203_left.jpeg
# 889
# D:\New folder\train_short\203_right.jpeg
# 890
# D:\New folder\train_short\2041_left.jpeg
# 891
# D:\New folder\train_short\2041_right.jpeg
# 892
# D:\New folder\train_short\2046_left.jpeg
# 893
# D:\New folder\train_short\2046_right.jpeg
# 894
# D:\New folder\train_short\2047_left.jpeg
# 895
# D:\New folder\train_short\2047_right.jpeg
# 896
# D:\New folder\train_short\2048_left.jpeg
# 897
# D:\New folder\train_short\2048_right.jpeg
# 898
# D:\New folder\train_short\204_left.jpeg
# 899
# D:\New folder\train_short\204_right.jpeg
# 900
# D:\New folder\train_short\2053_left.jpeg
# 901
# D:\New folder\train_short\2053_right.jpeg
# 902
# D:\New folder\train_short\2054_left.jpeg
# 903
# D:\New folder\train_short\2054_right.jpeg
# 904
# D:\New folder\train_short\2058_left.jpeg
# 905
# D:\New folder\train_short\2058_right.jpeg
# 906
# D:\New folder\train_short\2059_left.jpeg
# 907
# D:\New folder\train_short\2059_right.jpeg
# 908
# D:\New folder\train_short\2062_left.jpeg
# 909
# D:\New folder\train_short\2062_right.jpeg
# 910
# D:\New folder\train_short\2063_left.jpeg
# 911
# D:\New folder\train_short\2063_right.jpeg
# 912
# D:\New folder\train_short\2065_left.jpeg
# 913
# D:\New folder\train_short\2065_right.jpeg
# 914
# D:\New folder\train_short\2066_left.jpeg
# 915
# D:\New folder\train_short\2066_right.jpeg
# 916
# D:\New folder\train_short\2071_left.jpeg
# 917
# D:\New folder\train_short\2071_right.jpeg
# 918
# D:\New folder\train_short\2077_left.jpeg
# 919
# D:\New folder\train_short\2077_right.jpeg
# 920
# D:\New folder\train_short\2078_left.jpeg
# 921
# D:\New folder\train_short\2078_right.jpeg
# 922
# D:\New folder\train_short\2079_left.jpeg
# 923
# D:\New folder\train_short\2079_right.jpeg
# 924
# D:\New folder\train_short\2080_left.jpeg
# 925
# D:\New folder\train_short\2080_right.jpeg
# 926
# D:\New folder\train_short\2081_left.jpeg
# 927
# D:\New folder\train_short\2081_right.jpeg
# 928
# D:\New folder\train_short\2084_left.jpeg
# 929
# D:\New folder\train_short\2084_right.jpeg
# 930
# D:\New folder\train_short\2086_left.jpeg
# 931
# D:\New folder\train_short\2086_right.jpeg
# 932
# D:\New folder\train_short\2087_left.jpeg
# 933
# D:\New folder\train_short\2087_right.jpeg
# 934
# D:\New folder\train_short\208_left.jpeg
# 935
# D:\New folder\train_short\208_right.jpeg
# 936
# D:\New folder\train_short\2092_left.jpeg
# 937
# D:\New folder\train_short\2092_right.jpeg
# 938
# D:\New folder\train_short\2094_left.jpeg
# 939
# D:\New folder\train_short\2094_right.jpeg
# 940
# D:\New folder\train_short\2095_left.jpeg
# 941
# D:\New folder\train_short\2095_right.jpeg
# 942
# D:\New folder\train_short\2096_left.jpeg
# 943
# D:\New folder\train_short\2096_right.jpeg
# 944
# D:\New folder\train_short\2097_left.jpeg
# 945
# D:\New folder\train_short\2097_right.jpeg
# 946
# D:\New folder\train_short\2099_left.jpeg
# 947
# D:\New folder\train_short\2099_right.jpeg
# 948
# D:\New folder\train_short\20_left.jpeg
# 949
# D:\New folder\train_short\20_right.jpeg
# 950
# D:\New folder\train_short\2102_left.jpeg
# 951
# D:\New folder\train_short\2102_right.jpeg
# 952
# D:\New folder\train_short\2106_left.jpeg
# 953
# D:\New folder\train_short\2106_right.jpeg
# 954
# D:\New folder\train_short\2107_left.jpeg
# 955
# D:\New folder\train_short\2107_right.jpeg
# 956
# D:\New folder\train_short\2108_left.jpeg
# 957
# D:\New folder\train_short\2108_right.jpeg
# 958
# D:\New folder\train_short\210_left.jpeg
# 959
# D:\New folder\train_short\210_right.jpeg
# 960
# D:\New folder\train_short\2110_left.jpeg
# 961
# D:\New folder\train_short\2110_right.jpeg
# 962
# D:\New folder\train_short\2113_left.jpeg
# 963
# D:\New folder\train_short\2113_right.jpeg
# 964
# D:\New folder\train_short\2117_left.jpeg
# 965
# D:\New folder\train_short\2117_right.jpeg
# 966
# D:\New folder\train_short\211_left.jpeg
# 967
# D:\New folder\train_short\211_right.jpeg
# 968
# D:\New folder\train_short\2121_left.jpeg
# 969
# D:\New folder\train_short\2121_right.jpeg
# 970
# D:\New folder\train_short\2123_left.jpeg
# 971
# D:\New folder\train_short\2123_right.jpeg
# 972
# D:\New folder\train_short\2124_left.jpeg
# 973
# D:\New folder\train_short\2124_right.jpeg
# 974
# D:\New folder\train_short\2125_left.jpeg
# 975
# D:\New folder\train_short\2125_right.jpeg
# 976
# D:\New folder\train_short\2129_left.jpeg
# 977
# D:\New folder\train_short\2129_right.jpeg
# 978
# D:\New folder\train_short\2131_left.jpeg
# 979
# D:\New folder\train_short\2131_right.jpeg
# 980
# D:\New folder\train_short\2132_left.jpeg
# 981
# D:\New folder\train_short\2132_right.jpeg
# 982
# D:\New folder\train_short\2133_left.jpeg
# 983
# D:\New folder\train_short\2133_right.jpeg
# 984
# D:\New folder\train_short\2134_left.jpeg
# 985
# D:\New folder\train_short\2134_right.jpeg
# 986
# D:\New folder\train_short\2136_left.jpeg
# 987
# D:\New folder\train_short\2136_right.jpeg
# 988
# D:\New folder\train_short\2138_left.jpeg
# 989
# D:\New folder\train_short\2138_right.jpeg
# 990
# D:\New folder\train_short\2139_left.jpeg
# 991
# D:\New folder\train_short\2139_right.jpeg
# 992
# D:\New folder\train_short\2140_left.jpeg
# 993
# D:\New folder\train_short\2140_right.jpeg
# 994
# D:\New folder\train_short\2141_left.jpeg
# 995
# D:\New folder\train_short\2141_right.jpeg
# 996
# D:\New folder\train_short\2144_left.jpeg
# 997
# D:\New folder\train_short\2144_right.jpeg
# 998
# D:\New folder\train_short\2149_left.jpeg
# 999
# D:\New folder\train_short\2149_right.jpeg
# 1000
# D:\New folder\train_short\214_left.jpeg
# 1001
# D:\New folder\train_short\214_right.jpeg
# 1002
# D:\New folder\train_short\2155_left.jpeg
# 1003
# D:\New folder\train_short\2155_right.jpeg
# 1004
# D:\New folder\train_short\2157_left.jpeg
# 1005
# D:\New folder\train_short\2157_right.jpeg
# 1006
# D:\New folder\train_short\2159_left.jpeg
# 1007
# D:\New folder\train_short\2159_right.jpeg
# 1008
# D:\New folder\train_short\2161_left.jpeg
# 1009
# D:\New folder\train_short\2161_right.jpeg
# 1010
# D:\New folder\train_short\2163_left.jpeg
# 1011
# D:\New folder\train_short\2163_right.jpeg
# 1012
# D:\New folder\train_short\2164_left.jpeg
# 1013
# D:\New folder\train_short\2164_right.jpeg
# 1014
# D:\New folder\train_short\2168_left.jpeg
# 1015
# D:\New folder\train_short\2168_right.jpeg
# 1016
# D:\New folder\train_short\2169_left.jpeg
# 1017
# D:\New folder\train_short\2169_right.jpeg
# 1018
# D:\New folder\train_short\216_left.jpeg
# 1019
# D:\New folder\train_short\216_right.jpeg
# 1020
# D:\New folder\train_short\2174_left.jpeg
# 1021
# D:\New folder\train_short\2174_right.jpeg
# 1022
# D:\New folder\train_short\2179_left.jpeg
# 1023
# D:\New folder\train_short\2179_right.jpeg
# 1024
# D:\New folder\train_short\217_left.jpeg
# 1025
# D:\New folder\train_short\217_right.jpeg
# 1026
# D:\New folder\train_short\2180_left.jpeg
# 1027
# D:\New folder\train_short\2180_right.jpeg
# 1028
# D:\New folder\train_short\2181_left.jpeg
# 1029
# D:\New folder\train_short\2181_right.jpeg
# 1030
# D:\New folder\train_short\2182_left.jpeg
# 1031
# D:\New folder\train_short\2182_right.jpeg
# 1032
# D:\New folder\train_short\2185_left.jpeg
# 1033
# D:\New folder\train_short\2185_right.jpeg
# 1034
# D:\New folder\train_short\2188_left.jpeg
# 1035
# D:\New folder\train_short\2188_right.jpeg
# 1036
# D:\New folder\train_short\218_left.jpeg
# 1037
# D:\New folder\train_short\218_right.jpeg
# 1038
# D:\New folder\train_short\2190_left.jpeg
# 1039
# D:\New folder\train_short\2190_right.jpeg
# 1040
# D:\New folder\train_short\2191_left.jpeg
# 1041
# D:\New folder\train_short\2191_right.jpeg
# 1042
# D:\New folder\train_short\2192_left.jpeg
# 1043
# D:\New folder\train_short\2192_right.jpeg
# 1044
# D:\New folder\train_short\2194_left.jpeg
# 1045
# D:\New folder\train_short\2194_right.jpeg
# 1046
# D:\New folder\train_short\2199_left.jpeg
# 1047
# D:\New folder\train_short\2199_right.jpeg
# 1048
# D:\New folder\train_short\219_left.jpeg
# 1049
# D:\New folder\train_short\219_right.jpeg
# 1050
# D:\New folder\train_short\21_left.jpeg
# 1051
# D:\New folder\train_short\21_right.jpeg
# 1052
# D:\New folder\train_short\2200_left.jpeg
# 1053
# D:\New folder\train_short\2200_right.jpeg
# 1054
# D:\New folder\train_short\2203_left.jpeg
# 1055
# D:\New folder\train_short\2203_right.jpeg
# 1056
# D:\New folder\train_short\2204_left.jpeg
# 1057
# D:\New folder\train_short\2204_right.jpeg
# 1058
# ...
# 2534
# D:\New folder\train_short\616_right.jpeg
# 2535
# D:\New folder\train_short\617_left.jpeg
# 2536
# D:\New folder\train_short\617_right.jpeg
# 2537
# D:\New folder\train_short\621_left.jpeg
# 2538
# D:\New folder\train_short\621_right.jpeg
# 2539
# D:\New folder\train_short\622_left.jpeg
# 2540
# D:\New folder\train_short\622_right.jpeg
# 2541
# D:\New folder\train_short\623_left.jpeg
# 2542
# D:\New folder\train_short\623_right.jpeg
# 2543
# D:\New folder\train_short\625_left.jpeg
# 2544
# D:\New folder\train_short\625_right.jpeg
# 2545
# D:\New folder\train_short\627_left.jpeg
# 2546
# D:\New folder\train_short\627_right.jpeg
# 2547
# D:\New folder\train_short\62_left.jpeg
# 2548
# D:\New folder\train_short\62_right.jpeg
# 2549
# D:\New folder\train_short\632_left.jpeg
# 2550
# D:\New folder\train_short\632_right.jpeg
# 2551
# D:\New folder\train_short\634_left.jpeg
# 2552
# D:\New folder\train_short\634_right.jpeg
# 2553
# D:\New folder\train_short\636_left.jpeg
# 2554
# D:\New folder\train_short\636_right.jpeg
# 2555
# D:\New folder\train_short\639_left.jpeg
# 2556
# D:\New folder\train_short\639_right.jpeg
# 2557
# D:\New folder\train_short\641_left.jpeg
# 2558
# D:\New folder\train_short\641_right.jpeg
# 2559
# D:\New folder\train_short\642_left.jpeg
# 2560
# D:\New folder\train_short\642_right.jpeg
# 2561
# D:\New folder\train_short\643_left.jpeg
# 2562
# D:\New folder\train_short\643_right.jpeg
# 2563
# D:\New folder\train_short\644_left.jpeg
# 2564
# D:\New folder\train_short\644_right.jpeg
# 2565
# D:\New folder\train_short\645_left.jpeg
# 2566
# D:\New folder\train_short\645_right.jpeg
# 2567
# D:\New folder\train_short\64_left.jpeg
# 2568
# D:\New folder\train_short\64_right.jpeg
# 2569
# D:\New folder\train_short\650_left.jpeg
# 2570
# D:\New folder\train_short\650_right.jpeg
# 2571
# D:\New folder\train_short\65_left.jpeg
# 2572
# D:\New folder\train_short\65_right.jpeg
# 2573
# D:\New folder\train_short\660_left.jpeg
# 2574
# D:\New folder\train_short\660_right.jpeg
# 2575
# D:\New folder\train_short\662_left.jpeg
# 2576
# D:\New folder\train_short\662_right.jpeg
# 2577
# D:\New folder\train_short\666_left.jpeg
# 2578
# D:\New folder\train_short\666_right.jpeg
# 2579
# D:\New folder\train_short\668_left.jpeg
# 2580
# D:\New folder\train_short\668_right.jpeg
# 2581
# D:\New folder\train_short\669_left.jpeg
# 2582
# D:\New folder\train_short\669_right.jpeg
# 2583
# D:\New folder\train_short\66_left.jpeg
# 2584
# D:\New folder\train_short\66_right.jpeg
# 2585
# D:\New folder\train_short\670_left.jpeg
# 2586
# D:\New folder\train_short\670_right.jpeg
# 2587
# D:\New folder\train_short\673_left.jpeg
# 2588
# D:\New folder\train_short\673_right.jpeg
# 2589
# D:\New folder\train_short\677_left.jpeg
# 2590
# D:\New folder\train_short\677_right.jpeg
# 2591
# D:\New folder\train_short\678_left.jpeg
# 2592
# D:\New folder\train_short\678_right.jpeg
# 2593
# D:\New folder\train_short\679_left.jpeg
# 2594
# D:\New folder\train_short\679_right.jpeg
# 2595
# D:\New folder\train_short\67_left.jpeg
# 2596
# D:\New folder\train_short\67_right.jpeg
# 2597
# D:\New folder\train_short\681_left.jpeg
# 2598
# D:\New folder\train_short\681_right.jpeg
# 2599
# D:\New folder\train_short\682_left.jpeg
# 2600
# D:\New folder\train_short\682_right.jpeg
# 2601
# D:\New folder\train_short\685_left.jpeg
# 2602
# D:\New folder\train_short\685_right.jpeg
# 2603
# D:\New folder\train_short\686_left.jpeg
# 2604
# D:\New folder\train_short\686_right.jpeg
# 2605
# D:\New folder\train_short\687_left.jpeg
# 2606
# D:\New folder\train_short\687_right.jpeg
# 2607
# D:\New folder\train_short\690_left.jpeg
# 2608
# D:\New folder\train_short\690_right.jpeg
# 2609
# D:\New folder\train_short\694_left.jpeg
# 2610
# D:\New folder\train_short\694_right.jpeg
# 2611
# D:\New folder\train_short\696_left.jpeg
# 2612
# D:\New folder\train_short\696_right.jpeg
# 2613
# D:\New folder\train_short\698_left.jpeg
# 2614
# D:\New folder\train_short\698_right.jpeg
# 2615
# D:\New folder\train_short\700_left.jpeg
# 2616
# D:\New folder\train_short\700_right.jpeg
# 2617
# D:\New folder\train_short\702_left.jpeg
# 2618
# D:\New folder\train_short\702_right.jpeg
# 2619
# D:\New folder\train_short\703_left.jpeg
# 2620
# D:\New folder\train_short\703_right.jpeg
# 2621
# D:\New folder\train_short\704_left.jpeg
# 2622
# D:\New folder\train_short\704_right.jpeg
# 2623
# D:\New folder\train_short\706_left.jpeg
# 2624
# D:\New folder\train_short\706_right.jpeg
# 2625
# D:\New folder\train_short\70_left.jpeg
# 2626
# D:\New folder\train_short\70_right.jpeg
# 2627
# D:\New folder\train_short\710_left.jpeg
# 2628
# D:\New folder\train_short\710_right.jpeg
# 2629
# D:\New folder\train_short\715_left.jpeg
# 2630
# D:\New folder\train_short\715_right.jpeg
# 2631
# D:\New folder\train_short\717_left.jpeg
# 2632
# D:\New folder\train_short\717_right.jpeg
# 2633
# D:\New folder\train_short\721_left.jpeg
# 2634
# D:\New folder\train_short\721_right.jpeg
# 2635
# D:\New folder\train_short\723_left.jpeg
# 2636
# D:\New folder\train_short\723_right.jpeg
# 2637
# D:\New folder\train_short\728_left.jpeg
# 2638
# D:\New folder\train_short\728_right.jpeg
# 2639
# D:\New folder\train_short\72_left.jpeg
# 2640
# D:\New folder\train_short\72_right.jpeg
# 2641
# D:\New folder\train_short\731_left.jpeg
# 2642
# D:\New folder\train_short\731_right.jpeg
# 2643
# D:\New folder\train_short\732_left.jpeg
# 2644
# D:\New folder\train_short\732_right.jpeg
# 2645
# D:\New folder\train_short\733_left.jpeg
# 2646
# D:\New folder\train_short\733_right.jpeg
# 2647
# D:\New folder\train_short\734_left.jpeg
# 2648
# D:\New folder\train_short\734_right.jpeg
# 2649
# D:\New folder\train_short\735_left.jpeg
# 2650
# D:\New folder\train_short\735_right.jpeg
# 2651
# D:\New folder\train_short\736_left.jpeg
# 2652
# D:\New folder\train_short\736_right.jpeg
# 2653
# D:\New folder\train_short\739_left.jpeg
# 2654
# D:\New folder\train_short\739_right.jpeg
# 2655
# D:\New folder\train_short\73_left.jpeg
# 2656
# D:\New folder\train_short\73_right.jpeg
# 2657
# D:\New folder\train_short\740_left.jpeg
# 2658
# D:\New folder\train_short\740_right.jpeg
# 2659
# D:\New folder\train_short\743_left.jpeg
# 2660
# D:\New folder\train_short\743_right.jpeg
# 2661
# D:\New folder\train_short\745_left.jpeg
# 2662
# D:\New folder\train_short\745_right.jpeg
# 2663
# D:\New folder\train_short\747_left.jpeg
# 2664
# D:\New folder\train_short\747_right.jpeg
# 2665
# D:\New folder\train_short\74_left.jpeg
# 2666
# D:\New folder\train_short\74_right.jpeg
# 2667
# D:\New folder\train_short\752_left.jpeg
# 2668
# D:\New folder\train_short\752_right.jpeg
# 2669
# D:\New folder\train_short\754_left.jpeg
# 2670
# D:\New folder\train_short\754_right.jpeg
# 2671
# D:\New folder\train_short\75_left.jpeg
# 2672
# D:\New folder\train_short\75_right.jpeg
# 2673
# D:\New folder\train_short\760_left.jpeg
# 2674
# D:\New folder\train_short\760_right.jpeg
# 2675
# D:\New folder\train_short\761_left.jpeg
# 2676
# D:\New folder\train_short\761_right.jpeg
# 2677
# D:\New folder\train_short\762_left.jpeg
# 2678
# D:\New folder\train_short\762_right.jpeg
# 2679
# D:\New folder\train_short\765_left.jpeg
# 2680
# D:\New folder\train_short\765_right.jpeg
# 2681
# D:\New folder\train_short\766_left.jpeg
# 2682
# D:\New folder\train_short\766_right.jpeg
# 2683
# D:\New folder\train_short\768_left.jpeg
# 2684
# D:\New folder\train_short\768_right.jpeg
# 2685
# D:\New folder\train_short\773_left.jpeg
# 2686
# D:\New folder\train_short\773_right.jpeg
# 2687
# D:\New folder\train_short\780_left.jpeg
# 2688
# D:\New folder\train_short\780_right.jpeg
# 2689
# D:\New folder\train_short\783_left.jpeg
# 2690
# D:\New folder\train_short\783_right.jpeg
# 2691
# D:\New folder\train_short\784_left.jpeg
# 2692
# D:\New folder\train_short\784_right.jpeg
# 2693
# D:\New folder\train_short\787_left.jpeg
# 2694
# D:\New folder\train_short\787_right.jpeg
# 2695
# D:\New folder\train_short\78_left.jpeg
# 2696
# D:\New folder\train_short\78_right.jpeg
# 2697
# D:\New folder\train_short\791_left.jpeg
# 2698
# D:\New folder\train_short\791_right.jpeg
# 2699
# D:\New folder\train_short\792_left.jpeg
# 2700
# D:\New folder\train_short\792_right.jpeg
# 2701
# D:\New folder\train_short\793_left.jpeg
# 2702
# D:\New folder\train_short\793_right.jpeg
# 2703
# D:\New folder\train_short\796_left.jpeg
# 2704
# D:\New folder\train_short\796_right.jpeg
# 2705
# D:\New folder\train_short\799_left.jpeg
# 2706
# D:\New folder\train_short\799_right.jpeg
# 2707
# D:\New folder\train_short\79_left.jpeg
# 2708
# D:\New folder\train_short\79_right.jpeg
# 2709
# D:\New folder\train_short\800_left.jpeg
# 2710
# D:\New folder\train_short\800_right.jpeg
# 2711
# D:\New folder\train_short\802_left.jpeg
# 2712
# D:\New folder\train_short\802_right.jpeg
# 2713
# D:\New folder\train_short\803_left.jpeg
# 2714
# D:\New folder\train_short\803_right.jpeg
# 2715
# D:\New folder\train_short\805_left.jpeg
# 2716
# D:\New folder\train_short\805_right.jpeg
# 2717
# D:\New folder\train_short\810_left.jpeg
# 2718
# D:\New folder\train_short\810_right.jpeg
# 2719
# D:\New folder\train_short\812_left.jpeg
# 2720
# D:\New folder\train_short\812_right.jpeg
# 2721
# D:\New folder\train_short\814_left.jpeg
# 2722
# D:\New folder\train_short\814_right.jpeg
# 2723
# D:\New folder\train_short\818_left.jpeg
# 2724
# D:\New folder\train_short\818_right.jpeg
# 2725
# D:\New folder\train_short\819_left.jpeg
# 2726
# D:\New folder\train_short\819_right.jpeg
# 2727
# D:\New folder\train_short\81_left.jpeg
# 2728
# D:\New folder\train_short\81_right.jpeg
# 2729
# D:\New folder\train_short\820_left.jpeg
# 2730
# D:\New folder\train_short\820_right.jpeg
# 2731
# D:\New folder\train_short\825_left.jpeg
# 2732
# D:\New folder\train_short\825_right.jpeg
# 2733
# D:\New folder\train_short\829_left.jpeg
# 2734
# D:\New folder\train_short\829_right.jpeg
# 2735
# D:\New folder\train_short\82_left.jpeg
# 2736
# D:\New folder\train_short\82_right.jpeg
# 2737
# D:\New folder\train_short\831_left.jpeg
# 2738
# D:\New folder\train_short\831_right.jpeg
# 2739
# D:\New folder\train_short\838_left.jpeg
# 2740
# D:\New folder\train_short\838_right.jpeg
# 2741
# D:\New folder\train_short\839_left.jpeg
# 2742
# D:\New folder\train_short\839_right.jpeg
# 2743
# D:\New folder\train_short\842_left.jpeg
# 2744
# D:\New folder\train_short\842_right.jpeg
# 2745
# D:\New folder\train_short\844_left.jpeg
# 2746
# D:\New folder\train_short\844_right.jpeg
# 2747
# D:\New folder\train_short\845_left.jpeg
# 2748
# D:\New folder\train_short\845_right.jpeg
# 2749
# D:\New folder\train_short\84_left.jpeg
# 2750
# D:\New folder\train_short\84_right.jpeg
# 2751
# D:\New folder\train_short\851_left.jpeg
# 2752
# D:\New folder\train_short\851_right.jpeg
# 2753
# D:\New folder\train_short\857_left.jpeg
# 2754
# D:\New folder\train_short\857_right.jpeg
# 2755
# D:\New folder\train_short\862_left.jpeg
# 2756
# D:\New folder\train_short\862_right.jpeg
# 2757
# D:\New folder\train_short\863_left.jpeg
# 2758
# D:\New folder\train_short\863_right.jpeg
# 2759
# D:\New folder\train_short\865_left.jpeg
# 2760
# D:\New folder\train_short\865_right.jpeg
# 2761
# D:\New folder\train_short\866_left.jpeg
# 2762
# D:\New folder\train_short\866_right.jpeg
# 2763
# D:\New folder\train_short\869_left.jpeg
# 2764
# D:\New folder\train_short\869_right.jpeg
# 2765
# D:\New folder\train_short\876_left.jpeg
# 2766
# D:\New folder\train_short\876_right.jpeg
# 2767
# D:\New folder\train_short\877_left.jpeg
# 2768
# D:\New folder\train_short\877_right.jpeg
# 2769
# D:\New folder\train_short\878_left.jpeg
# 2770
# D:\New folder\train_short\878_right.jpeg
# 2771
# D:\New folder\train_short\879_left.jpeg
# 2772
# D:\New folder\train_short\879_right.jpeg
# 2773
# D:\New folder\train_short\880_left.jpeg
# 2774
# D:\New folder\train_short\880_right.jpeg
# 2775
# D:\New folder\train_short\885_left.jpeg
# 2776
# D:\New folder\train_short\885_right.jpeg
# 2777
# D:\New folder\train_short\886_left.jpeg
# 2778
# D:\New folder\train_short\886_right.jpeg
# 2779
# D:\New folder\train_short\897_left.jpeg
# 2780
# D:\New folder\train_short\897_right.jpeg
# 2781
# D:\New folder\train_short\899_left.jpeg
# 2782
# D:\New folder\train_short\899_right.jpeg
# 2783
# D:\New folder\train_short\904_left.jpeg
# 2784
# D:\New folder\train_short\904_right.jpeg
# 2785
# D:\New folder\train_short\905_left.jpeg
# 2786
# D:\New folder\train_short\905_right.jpeg
# 2787
# D:\New folder\train_short\906_left.jpeg
# 2788
# D:\New folder\train_short\906_right.jpeg
# 2789
# D:\New folder\train_short\909_left.jpeg
# 2790
# D:\New folder\train_short\909_right.jpeg
# 2791
# D:\New folder\train_short\910_left.jpeg
# 2792
# D:\New folder\train_short\910_right.jpeg
# 2793
# D:\New folder\train_short\912_left.jpeg
# 2794
# D:\New folder\train_short\912_right.jpeg
# 2795
# D:\New folder\train_short\914_left.jpeg
# 2796
# D:\New folder\train_short\914_right.jpeg
# 2797
# D:\New folder\train_short\916_left.jpeg
# 2798
# D:\New folder\train_short\916_right.jpeg
# 2799
# D:\New folder\train_short\917_left.jpeg
# 2800
# D:\New folder\train_short\917_right.jpeg
# 2801
# D:\New folder\train_short\921_left.jpeg
# 2802
# D:\New folder\train_short\921_right.jpeg
# 2803
# D:\New folder\train_short\925_left.jpeg
# 2804
# D:\New folder\train_short\925_right.jpeg
# 2805
# D:\New folder\train_short\928_left.jpeg
# 2806
# D:\New folder\train_short\928_right.jpeg
# 2807
# D:\New folder\train_short\929_left.jpeg
# 2808
# D:\New folder\train_short\929_right.jpeg
# 2809
# D:\New folder\train_short\930_left.jpeg
# 2810
# D:\New folder\train_short\930_right.jpeg
# 2811
# D:\New folder\train_short\931_left.jpeg
# 2812
# D:\New folder\train_short\931_right.jpeg
# 2813
# D:\New folder\train_short\932_left.jpeg
# 2814
# D:\New folder\train_short\932_right.jpeg
# 2815
# D:\New folder\train_short\934_left.jpeg
# 2816
# D:\New folder\train_short\934_right.jpeg
# 2817
# D:\New folder\train_short\935_left.jpeg
# 2818
# D:\New folder\train_short\935_right.jpeg
# 2819
# D:\New folder\train_short\936_left.jpeg
# 2820
# D:\New folder\train_short\936_right.jpeg
# 2821
# D:\New folder\train_short\939_left.jpeg
# 2822
# D:\New folder\train_short\939_right.jpeg
# 2823
# D:\New folder\train_short\940_left.jpeg
# 2824
# D:\New folder\train_short\940_right.jpeg
# 2825
# D:\New folder\train_short\941_left.jpeg
# 2826
# D:\New folder\train_short\941_right.jpeg
# 2827
# D:\New folder\train_short\943_left.jpeg
# 2828
# D:\New folder\train_short\943_right.jpeg
# 2829
# D:\New folder\train_short\945_left.jpeg
# 2830
# D:\New folder\train_short\945_right.jpeg
# 2831
# D:\New folder\train_short\947_left.jpeg
# 2832
# D:\New folder\train_short\947_right.jpeg
# 2833
# D:\New folder\train_short\953_left.jpeg
# 2834
# D:\New folder\train_short\953_right.jpeg
# 2835
# D:\New folder\train_short\958_left.jpeg
# 2836
# D:\New folder\train_short\958_right.jpeg
# 2837
# D:\New folder\train_short\959_left.jpeg
# 2838
# D:\New folder\train_short\959_right.jpeg
# 2839
# D:\New folder\train_short\95_left.jpeg
# 2840
# D:\New folder\train_short\95_right.jpeg
# 2841
# D:\New folder\train_short\960_left.jpeg
# 2842
# D:\New folder\train_short\960_right.jpeg
# 2843
# D:\New folder\train_short\963_left.jpeg
# 2844
# D:\New folder\train_short\963_right.jpeg
# 2845
# D:\New folder\train_short\966_left.jpeg
# 2846
# D:\New folder\train_short\966_right.jpeg
# 2847
# D:\New folder\train_short\967_left.jpeg
# 2848
# D:\New folder\train_short\967_right.jpeg
# 2849
# D:\New folder\train_short\968_left.jpeg
# 2850
# D:\New folder\train_short\968_right.jpeg
# 2851
# D:\New folder\train_short\969_left.jpeg
# 2852
# D:\New folder\train_short\969_right.jpeg
# 2853
# D:\New folder\train_short\970_left.jpeg
# 2854
# D:\New folder\train_short\970_right.jpeg
# 2855
# D:\New folder\train_short\971_left.jpeg
# 2856
# D:\New folder\train_short\971_right.jpeg
# 2857
# D:\New folder\train_short\977_left.jpeg
# 2858
# D:\New folder\train_short\977_right.jpeg
# 2859
# D:\New folder\train_short\978_left.jpeg
# 2860
# D:\New folder\train_short\978_right.jpeg
# 2861
# D:\New folder\train_short\979_left.jpeg
# 2862
# D:\New folder\train_short\979_right.jpeg
# 2863
# D:\New folder\train_short\980_left.jpeg
# 2864
# D:\New folder\train_short\980_right.jpeg
# 2865
# D:\New folder\train_short\983_left.jpeg
# 2866
# D:\New folder\train_short\983_right.jpeg
# 2867
# D:\New folder\train_short\985_left.jpeg
# 2868
# D:\New folder\train_short\985_right.jpeg
# 2869
# D:\New folder\train_short\986_left.jpeg
# 2870
# D:\New folder\train_short\986_right.jpeg
# 2871
# D:\New folder\train_short\987_left.jpeg
# 2872
# D:\New folder\train_short\987_right.jpeg
# 2873
# D:\New folder\train_short\990_left.jpeg
# 2874
# D:\New folder\train_short\990_right.jpeg
# 2875
# D:\New folder\train_short\992_left.jpeg
# 2876
# D:\New folder\train_short\992_right.jpeg
# 2877
# D:\New folder\train_short\994_left.jpeg
# 2878
# D:\New folder\train_short\994_right.jpeg
# 2879
# D:\New folder\train_short\997_left.jpeg
# 2880
# D:\New folder\train_short\997_right.jpeg
# 2881
# D:\New folder\train_short\998_left.jpeg
# 2882
# D:\New folder\train_short\998_right.jpeg
# 2883
# D:\New folder\train_short\99_left.jpeg
# 2884
# D:\New folder\train_short\99_right.jpeg
# 2885
# datarralen=2885
# labelarrlen=2885

# %%
labelsarr = np.array(labels).reshape(len(labels),1)
dataarr = np.array(data)

print(dataarr.shape)
print(labelsarr.shape)

totallen = len(dataarr)

X_train = dataarr[0:int(0.8*totallen)]
X_test =  dataarr[int(0.8*totallen):totallen]

Y_train_lab = labelsarr[0:int(0.8*totallen)] 
Y_test_lab = labelsarr[int(0.8*totallen):totallen]
# Out:
# (2885, 512, 512, 3)
# (2885, 1)

# %%
def OneHotEncoding(labeldata,classsize):
   retarr = np.zeros((len(labeldata),classsize))
   for i in range(0,len(labeldata)):
     retarr[i][labeldata[i]]=1

   return retarr

Y_train = OneHotEncoding(Y_train_lab,5)
Y_test = OneHotEncoding(Y_test_lab,5)



print(X_train.shape)
print(X_test.shape)

print(Y_train.shape)
print(Y_test.shape)
# Out:
# (2308, 512, 512, 3)
# (577, 512, 512, 3)
# (2308, 5)
# (577, 5)

# %%
x = tf.placeholder("float", shape=[None,512,512,3])
y_ = tf.placeholder("float", shape=[None,5])
keep_prob = tf.placeholder("float")


def conv2d(input_layer,ifilters,ikernel_size,istrides):
    layer = tf.layers.conv2d(inputs=input_layer,
      				      filters=ifilters,
				      kernel_size= ikernel_size,
                                      strides = istrides,
      				      padding="same",
				      activation = tf.nn.relu,
                                      kernel_initializer = tf.orthogonal_initializer(1.0),
                                      bias_initializer = tf.constant_initializer(0.1))
    return layer


def maxpool2d(input_layer,ipool_size,istrides):
    layer = tf.layers.max_pooling2d(inputs = input_layer,
				    pool_size = ipool_size,
				    strides = istrides,
				    padding= 'same')
    return layer   


def build_model():
    x_image = tf.reshape(x,[-1,512,512,3])
       
    layer = conv2d(x_image,32,[7,7],[2,2])
    layer =  maxpool2d(layer,[3,3],[2,2])  
          
    layer = conv2d(layer,32,[3,3],[1,1])
    layer = conv2d(layer,32,[3,3],[1,1]) 
    layer =  maxpool2d(layer,[3,3],[2,2])   
       
   
    layer = conv2d(layer,64,[3,3],[1,1])
    layer = conv2d(layer,64,[3,3],[1,1])  
    layer =  maxpool2d(layer,[3,3],[2,2])  

    layer = conv2d(layer,128,[3,3],[1,1])
    layer = conv2d(layer,128,[3,3],[1,1]) 
    layer = conv2d(layer,128,[3,3],[1,1])
    layer = conv2d(layer,128,[3,3],[1,1]) 
    layer =  maxpool2d(layer,[3,3],[2,2])  

    layer = conv2d(layer,256,[3,3],[1,1])
    layer = conv2d(layer,256,[3,3],[1,1]) 
    layer = conv2d(layer,256,[3,3],[1,1])
    layer = conv2d(layer,256,[3,3],[1,1]) 
    layer =  maxpool2d(layer,[3,3],[2,2])  
  
    layer = tf.layers.dropout(layer,0.5)        
 
    layer = tf.layers.Flatten()(layer)  
     
    layer = tf.layers.dense(layer,
                        1024,
   			kernel_initializer = tf.orthogonal_initializer(1.0),
   		        bias_initializer = tf.constant_initializer(0.1))              

    layer = tf.nn.relu(layer)
    layer = tf.layers.dropout(layer,0.5) 

    layer = tf.layers.dense(layer,
                        5,
   			kernel_initializer = tf.orthogonal_initializer(1.0),
   		        bias_initializer = tf.constant_initializer(0.1)) 
    layer =  tf.nn.softmax(layer)

    return layer


def next_batch(batch_size, data, labels,offset):
    batchX = data[offset:(offset+batch_size),:]
    batchY = labels[offset:(offset+batch_size),:] 
    return batchX,batchY

# %%
def train():    
    batch_size = 5
    for i in range(0,2000): 
        offset =(i*batch_size)%(len(X_train)-batch_size)  
        batch = next_batch(batch_size,X_train,Y_train,offset)
        if i%100 == 0:
            train_accuracy = accuracy.eval(feed_dict={ x: batch[0], y_: batch[1], keep_prob: 1.0})  
            print ("Step: %d, Training accuracy = %g" % (i, train_accuracy))
        train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})
 
def testandPrintAccuracy():
    batch_size = 20
    for i in range(0,1000):
       offset =(i*batch_size)%(len(X_test)-batch_size)
       batch = next_batch(batch_size,X_test,Y_test,offset)
       if i%100 == 0:
           print( "Step %d, Test accuracy = %g" %(i, accuracy.eval(feed_dict={x:batch[0], y_: batch[1], keep_prob: 1.0})) )

# %%
model = build_model()
cross_entropy = -tf.reduce_sum(y_ * tf.log(model))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(model, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

config = tf.ConfigProto()
config.gpu_options.allow_growth = False
init = tf.global_variables_initializer()
sess = tf.InteractiveSession(config=config)
sess.run(init)

train()
testandPrintAccuracy()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py:1711: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Step: 0, Training accuracy = 0.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-793c58a61681> in <module>()
#      12 sess.run(init)
#      13
# ---> 14 train()
#      15 testandPrintAccuracy()
#
# <ipython-input-10-6b848312be70> in train()
#       7             train_accuracy = accuracy.eval(feed_dict={ x: batch[0], y_: batch[1], keep_prob: 1.0})
#       8             print ("Step: %d, Training accuracy = %g" % (i, train_accuracy))
# ----> 9         train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})
#      10
#      11 def testandPrintAccuracy():
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in run(self, feed_dict, session)
#    2375         none, the default session will be used.
#    2376     """
# -> 2377     _run_using_default_session(self, feed_dict, self.graph, session)
#    2378
#    2379 _gradient_registry = registry.Registry("gradient")
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _run_using_default_session(operation, feed_dict, graph, session)
#    5213                        "the operation's graph is different from the session's "
#    5214                        "graph.")
# -> 5215   session.run(operation, feed_dict)
#    5216
#    5217
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
print(data)
# Out:
# []

# %%
print(len(data))
# Out:
# 0

# %%
print(i)
# Out:
# 1

# %%
print(len(data))
# Out:
# 0
